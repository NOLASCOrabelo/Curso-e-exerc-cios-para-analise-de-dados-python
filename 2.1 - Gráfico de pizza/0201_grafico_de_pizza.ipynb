# %% [markdown]
# <a href="https://colab.research.google.com/github/NOLASCOrabelo/Curso-e-exerc-cios-para-analise-de-dados-python/blob/main/2.1%20-%20Gr%C3%A1fico%20de%20pizza/0201_grafico_de_pizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/0201_grafico_de_pizza.csv')

# %%
df.head()
# Out:
#                name  birth_year  birth_date                birthplace  \
# 0    Marie Dressler        1868  1868-11-02  Cobourg, Ontario, Canada
# 1     George Arliss        1868  1868-04-10           London, England
# 2      Edmund Gwenn        1875  1875-09-26  Vale of Glamorgan, Wales
# 3    Charles Coburn        1877  1877-06-17              Savannah, Ga
# 4  Lionel Barrymore        1878  1878-04-28          Philadelphia, Pa
#
#   race_ethnicity        religion sexual_orientation  year_edition  \
# 0          White             NaN           Straight          1931
# 1          White             NaN           Straight          1930
# 2          White             NaN                 Na          1948
# 3          White             NaN           Straight          1944
# 4          White  Roman Catholic           Straight          1931
#
#                 category                   movie
# 0           Best Actress            Min and Bill
# ...

# %%
df_aniversario = df[['sexual_orientation']].groupby(['sexual_orientation'], as_index=False).value_counts()

# %%
df_aniversario
# Out:
#   sexual_orientation  count
# 0           Bisexual     20
# 1                Gay      7
# 2            Lesbian      2
# 3  Matter of Dispute      3
# 4                 Na     10
# 5           Straight    373

# %%
fig,ax = plt.subplots()
ax.pie(df_aniversario['count'], labels=df_aniversario['sexual_orientation'], autopct='%1.1f%%')
plt.show()

# %%
sexualidades = ['Gay', 'Lesbian', 'Straight']
id_sexualidade = [7, 2, 373]

# %%
fig,ax = plt.subplots()
ax.pie(id_sexualidade, labels=sexualidades, autopct='%1.1f%%', explode=[0, 0.5, 0] )
plt.show()
