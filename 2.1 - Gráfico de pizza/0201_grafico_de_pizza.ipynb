# %% [markdown]
# <a href="https://colab.research.google.com/github/NOLASCOrabelo/Curso-e-exerc-cios-para-analise-de-dados-python/blob/main/2.1%20-%20Gr%C3%A1fico%20de%20pizza/0201_grafico_de_pizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/baixados.csv')

# %%
df.head()
# Out:
#   ID_Produto                 Nome_Produto   Categoria    Marca  \
# 0    PROD001      Filtro de Óleo do Motor       Motor    Bosch
# 1    PROD002     Jogo de Velas de Ignição       Motor      NGK
# 2    PROD003  Pastilha de Freio Dianteira      Freios  Fras-le
# 3    PROD004        Amortecedor Dianteiro   Suspensão    Cofap
# 4    PROD005       Limpador de Para-brisa  Acessórios     Dyna
#
#               Modelo_Compativel Ano_Compativel  Preco_Venda  Estoque
# 0   Toyota Corolla, Honda Civic      2018-2023        45.50      150
# 1    Volkswagen Gol, Fiat Palio      2015-2022        89.90       85
# 2  Chevrolet Onix, Hyundai HB20      2019-2024       120.00      110
# 3         Ford Ka, Renault Kwid      2017-2023       280.75       40
# 4                     Universal      2010-2025        35.00      200

# %%
df_marcas = df[['Marca']].groupby(['Marca'], as_index=False).value_counts()

# %%
df_marcas
# Out:
#        Marca  count
# 0      Arteb      1
# 1      Bosch      1
# 2      Cofap      1
# 3       Dyna      1
# 4    Fras-le      1
# 5      Gates      1
# 6       Grid      1
# 7        Luk      1
# 8      Mobil      1
# 9      Moura      1
# 10       NGK      1
# 11  Petronas      1
# 12   Philips      1
# 13   Pirelli      1
# 14     Varga      1

# %%
M = ['Moura', 'Mobil']
ID_marcas = [1, 1]

# %%
fig,ax = plt.subplots()
ax.pie(ID_marcas, labels=M, autopct='%1.1f%%', explode=[0.05, 0.05], colors=['Gray', 'Black'])
plt.show()
